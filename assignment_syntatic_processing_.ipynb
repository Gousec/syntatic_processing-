# %%
# !pip install pycrf
# !pip install sklearn-crfsuite

import spacy
import sklearn_crfsuite
from sklearn_crfsuite import metrics
from collections import Counter

model = spacy.load("en_core_web_sm")

# %%
# Load the training data and its corresponding labels
with open('test_sent', 'r') as file:
    sent_doc = file.read()
with open('test_label', 'r') as file:
    label_doc = file.read()

# %%
sent_doc
# Out:
# "Furthermore\n,\nwhen\nall\ndeliveries\nwere\nanalyzed\n,\nregardless\nof\nrisk\nstatus\nbut\nlimited\nto\ngestational\nage\n>\nor\n=\n36\nweeks\n,\nthe\nrates\ndid\nnot\nchange\n(\n12.6\n%\n,\n280\nof\n2214\n;\nprimary\n9.2\n%\n,\n183\nof\n1994\n)\n\nAs\nthe\nambient\ntemperature\nincreases\n,\nthere\nis\nan\nincrease\nin\ninsensible\nfluid\nloss\nand\nthe\npotential\nfor\ndehydration\n\nThe\ndaily\nhigh\ntemperature\nranged\nfrom\n71\nto\n104\ndegrees\nF\nand\nAFI\nvalues\nranged\nfrom\n1.7\nto\n24.7\ncm\nduring\nthe\nstudy\nperiod\n\nThere\nwas\na\nsignificant\ncorrelation\nbetween\nthe\n2-\n,\n3-\n,\nand\n4-day\nmean\ntemperature\nand\nAFI\n,\nwith\nthe\n4-day\nmean\nbeing\nthe\nmost\nsignificant\n(\nr\n=\n0.31\n,\np\n&\n#\n60\n;\n0.001\n)\n\nFluctuations\nin\nambient\ntemperature\nare\ninversely\ncorrelated\nto\nchanges\nin\nAFI\n\nThis\nstudy\ntested\nthe\nhypothesis\nthat\nto\nreduce\nthe\nrate\nof\nmacrosomic\ninfants\nin\ngestational\ndiabetes\ncases\n,\ngood\nglycemic\ncontrol\nshould\nbe\ninitiated\nbefore\n34\ncompleted\ngestational\nweeks\n\nIn\nthe\n``\nearly\n''\nand\n``\nlate\n''\ngroups\n,\nmean\ngestational\nage\nat\nthe\nbeginning\nof\ntreatment\nwas\n30.0\n+/-\n3.8\nand\n36.2\n+/-\n1.2\nweeks\n,\nand\nduration\nof\ntreatment\nwas\n9.6\n+/-\n4.1\nand\n3.7\n+/-\n1.8\nweeks\n,\nrespectively\n\nThe\nrate\nof\nmacrosomic\nand\nlarge-for-gestational-age\ninfants\nwere\n5\nand\n11\n%\n,\nrespectively\n,\nin\nthe\nearly\ngroup\nas\ncompared\nto\n25\nand\n29\n%\nin\nthe\n``\nlate\n''\ngroup\n(\np\n&\n#\n60\n;\n0.05\n)\n\nIn\nour\nstudy\n,\nwe\nspecifically\nanalyzed\nthe\nrole\nplayed\nby\nadvanced\nmaternal\nage\nand\nsonographically\ndiscovered\nabnormalities\nin\nthe\ndetection\nof\nautosomal\ntrisomies\n\nAll\ntogether\n,\n27\nfetuses\nhad\nthis\ndisorder\n,\nrepresenting\n28.7\n%\n(\n27\nof\n94\n)\nof\nall\ncytogenetic\naberrations\ndetected\nat\nour\ncenter\nover\nthe\nsame\nperiod\n\nThe\nmost\ncommon\nindication\nleading\nto\ndiagnosis\nwas\nabnormal\nultrasound\nfinding\n(\n48.2\n%\n)\n,\nfollowed\nby\nadvanced\nmaternal\nage\n(\n44.4\n%\n)\n\nHowever\n,\n63\n%\nof\nthe\ntrisomic\nfetuses\nbelonged\nto\nmothers\naged\n35\nyears\nand\nabove\n\nTrisomy\n18\nfetuses\nshowed\nhydramnios\n,\nintrauterine\ngrowth\nretardation\n,\nmicrocephaly\n,\nspina\nbifida\n,\nand\nnonimmune\nhydrops\nfetalis\n\nThe\nobjective\nof\nthis\nstudy\nwas\nto\ndetermine\nif\nthe\nrate\nof\npreeclampsia\nis\nincreased\nin\ntriplet\nas\ncompared\nto\ntwin\ngestations\n\nThese\nwere\nmatched\nfor\nmaternal\nage\n,\nparity\n,\nand\nrace\nto\ntwin\ngestations\n(\nN\n=\n53\n)\nfrom\nthe\nsame\npopulation\n\nThe\nrate\nof\nsevere\npreeclampsia\nwas\nincreased\nsignificantly\nin\nthe\ntriplet\ngroup\n12\nof\n53\n(\n22.6\n%\n)\nas\ncompared\nwith\nthe\ntwin\ngroup\n3\nof\n53\n(\n5.7\n%\n)\n(\nOR\n=\n4.9\n,\n95\n%\nCI\n1.2-23.5\n,\np\n=\n0.02\n)\n\nWe\nconducted\na\nsurvey\nand\naudit\nof\nthermal\nequipment\nuse\nin\nvery\nlow-birth-weight\ninfants\nin\nfive\nOhio\nneonatal\nintensive\ncare\nunits\n(\nNICUs\n)\nto\ndocument\nregional\npractice\n\nThe\ninfant\npresented\nwith\nextreme\npallor\n,\nhypotonia\n,\nhepatosplenomegaly\n,\nand\nascites\n\nThe\ninitial\nhemoglobin\nwas\n2.2\ng/dL\n,\nthe\nKleihauer-Betke\nstain\nwas\n27.6\n%\n(\nhighest\nlevel\never\nreported\n)\n\nRight\ntemporal\nand\ncerebellar\nhemorrhages\nwere\npresent\n\nSequelae\ninclude\nsevere\ndevelopmental\ndelay\nand\nasymmetric\ndouble\nhemiplegia\n\nA\nsubchorial\nplacental\nhematoma\n,\nwhich\ndetected\nas\na\nsubchorial\nplacental\nlucencies\nby\nultrasonography\n,\ncan\nbe\na\ncause\nof\nreversible\nnonimmune\nhydrops\nfetalis\n\nSETTING\n:\nClinic\npopulations\nin\nthe\ncontinental\nUnited\nStates\n\nSibpair\nanalysis\n(\nn=54\n)\nresulted\nin\nmaximum\nlod\nscores\n(\nMLSs\n)\nof\n1.5\n,\n2.6\n,\n3.2\n,\nand\n2.3\nfor\nthese\nmarkers\n,\nwith\na\npeak\nmultipoint\nMLS\nof\n3.5\n\nA\npriori\nstratification\nby\nAPOE\ngenotype\nidentified\n27\nfamilies\nthat\nhad\na ...

# %%
len(sent_doc)
# Out:
# 121020

# %%
len(label_doc)
# Out:
# 38292

# %%
# Function to convert the lines into sentences
#
# Read each line from the input file and append it to form a sentence
# The output will return a python list of sentences
#
def make_sentences_from_words(filename):
    # Open the file, read it line by line and store those in a variable
    file_pointer = open(filename, 'r')
    file_content = file_pointer.readlines() 
    file_pointer.close()

    # An empty list to store all the sentences
    sentence_list = [] 

    # Initialising the sentence variable to store a sentence by appending words
    sentence = ""

    # Scroll through each line of the file content variable
    for word in file_content:
        # Remove leading and trailing spaces from the line
        word = word.strip() 
        # If the line is empty, it means it is the end or the beginning of a sentence 
        # add the current content to go into a new element in the sentence_list
        if word == "": 
            # Go into a new element
            sentence_list.append(sentence)
            # Reset the sentence variable
            sentence = ""; 
        else:
        # if word != "": 
            if sentence: #if non-empty, add new word after space
                sentence += " "+word
            else:
                sentence = word # first word, no space required

    return sentence_list

# %%
# Let's test the function
print(make_sentences_from_words("test_sent"))
# Out:
# ['Furthermore , when all deliveries were analyzed , regardless of risk status but limited to gestational age > or = 36 weeks , the rates did not change ( 12.6 % , 280 of 2214 ; primary 9.2 % , 183 of 1994 )', 'As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration', 'The daily high temperature ranged from 71 to 104 degrees F and AFI values ranged from 1.7 to 24.7 cm during the study period', 'There was a significant correlation between the 2- , 3- , and 4-day mean temperature and AFI , with the 4-day mean being the most significant ( r = 0.31 , p & # 60 ; 0.001 )', 'Fluctuations in ambient temperature are inversely correlated to changes in AFI', 'This study tested the hypothesis that to reduce the rate of macrosomic infants in gestational diabetes cases , good glycemic control should be initiated before 34 completed gestational weeks', "In the `` early '' and `` late '' groups , mean gestational age at the beginning of treatment was 30.0 +/- 3.8 and 36.2 +/- 1.2 weeks , and duration of treatment was 9.6 +/- 4.1 and 3.7 +/- 1.8 weeks , respectively", "The rate of macrosomic and large-for-gestational-age infants were 5 and 11 % , respectively , in the early group as compared to 25 and 29 % in the `` late '' group ( p & # 60 ; 0.05 )", 'In our study , we specifically analyzed the role played by advanced maternal age and sonographically discovered abnormalities in the detection of autosomal trisomies', 'All together , 27 fetuses had this disorder , representing 28.7 % ( 27 of 94 ) of all cytogenetic aberrations detected at our center over the same period', 'The most common indication leading to diagnosis was abnormal ultrasound finding ( 48.2 % ) , followed by advanced maternal age ( 44.4 % )', 'However , 63 % of the trisomic fetuses belonged to mothers aged 35 years and above', 'Trisomy 18 fetuses showed hydramnios , intrauterine growth retardation , microcephaly , spina bifida , and nonimmune hydrops fetalis', 'The objective of this study was to determine if the rate of preeclampsia is increased in triplet as compared to twin gestations', 'These were matched for maternal age , parity , and race to twin gestations ( N = 53 ) from the same population', 'The rate of severe preeclampsia was increased significantly in the triplet group 12 of 53 ( 22.6 % ) as compared with the twin group 3 of 53 ( 5.7 % ) ( OR = 4.9 , 95 % CI 1.2-23.5 , p = 0.02 )', 'We conducted a survey and audit of thermal equipment use in very low-birth-weight infants in five Ohio neonatal intensive care units ( NICUs ) to document regional practice', 'The infant presented with extreme pallor , hypotonia , hepatosplenomegaly , and ascites', 'The initial hemoglobin was 2.2 g/dL , the Kleihauer-Betke stain was 27.6 % ( highest level ever reported )', 'Right temporal and cerebellar hemorrhages were present', 'Sequelae include severe developmental delay and asymmetric double hemiplegia', 'A subchorial placental hematoma , which detected as a subchorial placental lucencies by ultrasonography , can be a cause of reversible nonimmune hydrops fetalis', 'SETTING : Clinic populations in the continental United States', 'Sibpair analysis ( n=54 ) resulted in maximum lod scores ( MLSs ) of 1.5 , 2.6 , 3.2 , and 2.3 for these markers , with a peak multipoint MLS of 3.5', 'A priori stratification by APOE genotype identified 27 families that had at least 1 member with AD whose genotype did not contain an APOE*4 allele', 'CONCLUSIONS : A complete genomic screen in families affected with late-onset AD identified 4 regions of interest after follow-up', 'Chromosome 12 gave the strongest and most consistent results with a peak multipoint MLS of 3.5 , suggesting that this region contains a new susceptibility gene for AD', 'CONTEXT : A mutation in the BRCA1 gene may confer substantial risk for breast and/or ovarian cancer', 'DESIGN : A complete sequence analysis of the BRCA1 coding sequence and flanking intronic regions was ...

# %%
# Load the files into lists using the function
train_sentences = make_sentences_from_words("train_sent")
train_labels = make_sentences_from_words("train_label")
test_sentences = make_sentences_from_words("test_sent")
test_labels = make_sentences_from_words("test_label")

# %%
print(train_sentences[1])
print(train_labels[1])
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# O O O O O O O O O O O O O O O O O O O O O O O O O

# %%
print(train_sentences[1])
print(train_labels[1])
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# O O O O O O O O O O O O O O O O O O O O O O O O O

# %%
# No. of sentences in the processed train and test dataset
train_sentence_count = len(train_sentences)
test_sentence_count = len(test_sentences)
print("The number of training sentences are ", train_sentence_count)
print("The number of test sentences are ", test_sentence_count)
print("The teo tal number of sentences are ", train_sentence_count + test_sentence_count)
print("Ratio of train:test sentences is 1:", test_sentence_count/train_sentence_count)
print("The percentage of test sentences over train is ", round(test_sentence_count*100/train_sentence_count, 2), "%")
# Out:
# The number of training sentences are  2599
# The number of test sentences are  1056
# The teo tal number of sentences are  3655
# Ratio of train:test sentences is 1: 0.40631011927664484
# The percentage of test sentences over train is  40.63 %

# %%
# No. of labels in the processed train and test dataset
train_label_count = len(train_labels)
test_label_count = len(test_labels)
print("The number of training labels are ", train_label_count)
print("The number of test labels are ", test_label_count)
print("The teo tal number of labels are ", train_label_count + test_label_count)
print("Ratio of train:test labels is 1:", test_label_count/train_label_count)
print("The percentage of test labels over train is ", round(test_label_count*100/train_label_count, 2), "%")
# Out:
# The number of training labels are  2599
# The number of test labels are  1056
# The teo tal number of labels are  3655
# Ratio of train:test labels is 1: 0.40631011927664484
# The percentage of test labels over train is  40.63 %

# %%
# We use POS tags to identify the token types and filter out the NOUN and PROPN types

pos_noun_list = {} # Empty dictionary to store the POS tags
pos_propn_list = {}

# Scroll through the sentence list; pass each sentence into the Spacy model and extract the tokens
for sentence in train_sentences:
    processed_sentence = model(sentence)
    for token in processed_sentence:
        # print(token.text, token.pos_, token.tag_)
        # print(token.text, " -- ", token.pos_)
        if token.pos_ == "NOUN":
            # Store the POS tag along with the corresponding test and add 1 to its count when there's a match
            pos_noun_list[token.text] = pos_noun_list.get(token.text, 0) + 1;
        if token.pos_ == "PROPN":
            # Store the POS tag along with the corresponding test and add 1 to its count when there's a match
            pos_propn_list[token.text] = pos_propn_list.get(token.text, 0) + 1;

# %%
pos_noun_list
# Out:
# {'births': 1,
#  'weeks': 27,
#  'delivery': 18,
#  'route': 2,
#  'indication': 3,
#  'age': 34,
#  'parity': 1,
#  'practice': 22,
#  'group': 63,
#  'risk': 49,
#  'status': 14,
#  'rate': 46,
#  '%': 161,
#  'presentation': 6,
#  'medicine': 29,
#  'patients': 354,
#  'Arrest': 1,
#  'dilation': 1,
#  'subgroups': 1,
#  'rates': 22,
#  'care': 47,
#  'hospitals': 8,
#  'community': 11,
#  'groups': 23,
#  'trimester': 4,
#  'fluid': 5,
#  'index': 11,
#  'temperature': 5,
#  'increases': 6,
#  'decrease': 3,
#  'period': 22,
#  'heat': 2,
#  'women': 48,
#  'singleton': 1,
#  'pregnancies': 7,
#  'gestation': 4,
#  'testing': 15,
#  'determinations': 2,
#  'ambient': 1,
#  'area': 8,
#  'day': 27,
#  'mean': 1,
#  'test': 15,
#  'date': 2,
#  'rank': 1,
#  'Correlation': 3,
#  'relationship': 9,
#  'account': 4,
#  'measure': 3,
#  'well': 1,
#  'being': 2,
#  'study': 103,
#  'population': 23,
#  'diabetes': 23,
#  'screening': 10,
#  'clinic': 4,
#  'year': 27,
#  'treatment': 195,
#  'week': 6,
#  'protocol': 4,
#  'control': 29,
#  'characteristics': 14,
#  'differences': 13,
#  'mode': 3,
#  'scores': 4,
#  'infants': 17,
#  'cases': 46,
#  'aim': 7,
#  'contribution': 3,
#  'markers': 18,
#  'diagnosis': 40,
#  'fetuses': 6,
#  'years': 45,
#  'syndrome': 45,
#  'trisomies': 1,
#  'anomalies': 4,
#  'signs': 5,
#  'Trisomy': 1,
#  'features': 13,
#  'hydramnios': 1,
#  'malformations': 9,
#  'pyelectasis': 1,
#  'Signs': 1,
#  'trisomy': 1,
#  'growth': 27,
#  'retardation': 1,
#  'oligoanhydramnios': 1,
#  'bradycardia': 3,
#  'hydronephrosis': 1,
#  'triplet': 3,
#  'preeclampsia': 1,
#  'criteria': 11,
#  't': 8,
#  'analysis': 47,
#  'case': 36,
#  'pre': 3,
#  '-': 18,
#  'gestations': 2,
#  'twins': 1,
#  'information': 13,
#  'order': 7,
#  'survey': 6,
#  'variety': 5,
#  'styles': 1,
#  'NICUs': 2,
#  'incubators': 2,
#  'warmers': 3,
#  'ages': 4,
#  'audit': 4,
#  'use': 53,
#  'plastic': 2,
#  'covers': 1,
#  'mattresses': 1,
#  'humidity': 1,
#  'discrepancies': 1,
#  'responses': 11,
#  'variability': 3,
#  'equipment': 3,
#  'management': 34,
#  'report': 24,
#  'term': 39,
#  'hemorrhage': 6,
#  'movements': 4,
#  'hr': 2,
#  'nonstress': 1,
#  'profile': 4,
#  'beat': 2,
#  'anus': 2,
#  'defects': 11,
#  'complex': 5,
#  'combination': 44,
#  'exstrophy': 2,
#  'bladder': 6,
#  'defect': 1,
#  'development': 12,
#  'mesoderm': 2,
#  'mesenchyme': 1,
#  'septum': 1,
#  'vertebrae': 1,
#  'meningomyeloceles': 2,
#  'limb': 3,
#  'inheritance': 1,
#  'association': 16,
#  'survival': 50,
#  'surgery': 51,
#  'meningomyelocele': 1,
#  'aplasia': 1,
#  'patient': 44,
#  'quality': 9,
#  'life': 15,
#  'counseling': 2,
#  'family': 17,
#  'obstetricians': 1,
#  'surgeons': 2,
#  'urologists': 1,
#  'neurosurgeons': 1,
#  'neonatologists': 1,
#  'hydrops': 3,
#  'fetails': 1,
#  'ascites': 1,
#  'hydrothorax': 1,
#  'effusion': 2,
#  'regression': 7,
#  'lucencies': 1,
#  'cord': 7,
#  'insertion': 4,
#  'inspection': 2,
#  'placenta': 1,
#  'lesion': 4,
#  'fibrin': 1,
#  'deposits': 1,
#  'site': 17,
#  'absorption': 4,
#  'diseases': 16,
#  'multisystem': 1,
#  'disorders': 17,
#  'presence': 12,
#  'mitochondria': 1,
#  'reports': 5,
#  'woman': 5,
#  'preterm': 7,
#  'labor': 5,
#  'hypertension': 8,
#  'CONTEXT': 2,
#  'loci': 6,
#  'disease': 105,
#  'AD': 7,
#  'amyloid': 4,
#  'precursor': 1,
#  'protein': 42,
#  'gene': 54,
#  'E': 6,
#  'OBJECTIVE': 20,
#  'factors': 22,
#  'onset': 9,
#  'screen': 4,
#  'values': 9,
#  'follow': 6,
#  'up': 10,
#  'P': 30,
#  'value': 11,
#  'pair': 2,
#  'lod': 3,
#  'score': 5,
#  'data': 40,
#  'PATIENTS': 5,
#  'series': 6,
#  'families': 18,
#  'subset': 5,
#  'members': 7,
#  'OUTCOME': 7,
#  'MEASURES': 3,
#  'Linkage': 1,
#  'results': 54,
#  'model': 17,
#  'methods': 28,
#  'RESULTS': 27,
#  'regions': 7,
#  'analyses': 8,
#  'interest': 6,
#  'chromosomes': 3,
#  'Peak': 1,
#  'point': 2,
#  'affecteds': 1,
#  'pairs': 3,
#  'D12S373': 1,
#  'D12S1057': 1,
#  'D12S390': 1,
#  'Analysis': 2,
#  'MLSs': 1,
#  'peak': 4,
#  'multipoint': 1,
#  'chromosome': 10,
#  'susceptibility': 11,
#  'knowledge': 5,
#  'mutations': 19,
#  'mutation': 13,
#  'breast': 17,
#  'cancer': 135,
#  'participant': 1,
#  'linkage': 4,
#  'locus': 6,
#  'Sequence': 2,
#  'variants': 3,
#  'sample': 6,
#  'alterations': 3,
#  'significance': 6,
#  'polymorphisms': 5,
#  'bias': 1,
#  'Characteristics': 2,
#  'ethnicity': 1,
#  'history': 9,
#  'probability': 3,
#  'prostate': 18,
#  'Prostate': 1,
#  'reference': 6,
#  'comparison': 18,
#  'men': 16,
#  'basis': 8,
#  'haplotype': 3,
#  'region': 16,
#  'antigen': 8,
#  'levels': 17,
#  'examination': 8,
#  'stage': 30,
#  'grade': 16,
#  'cancers': 12,
#  'occurrence': 5,
#  'P=.03': 1,
#  'parameters': 11,
#  'excess': 4,
#  'colon': 6,
#  'difference': 9,
#  'tumors': 28,
#  'fraction': 4,
#  'stages': 7,
#  'importance': 6,
#  'detection': 15,
#  'genes': 14,
#  'findings': 15,
#  'recommendations': 3,
#  'Susceptibility': 1,
#  'sclerosis': 6,
#  'component': 5,
#  '6p21.3': 1,
#  'APOE': 1,
#  'myelin': 2,
#  'SUBJECTS': 4,
#  'total': 5,
#  'individuals': 4,
#  'alleles': 2,
#  'haplotypes': 3,
#  'Haplotype': 1,
#  'frequencies': 2,
#  'likelihood': 3,
#  'effect': 43,
#  'class': 10,
#  'contributions': 2,
#  'distribution': 7,
#  'samples': 11,
#  'variation': 3,
#  'influence': 7,
#  'location': 2,
#  'survivors': 3,
#  'childhood': 6,
#  'retinoblastoma': 10,
#  'role': 32,
#  'radiotherapy': 22,
#  'incidence': 17,
#  'median': 3,
#  'radiation': 21,
#  'response': 43,
#  'bone': 39,
#  'tissue': 20,
#  'sarcomas': 8,
#  'PARTICIPANTS': 1,
#  'hospital': 12,
#  'records': 6,
#  'Incidence': 2,
#  'RR': 1,
#  'confidence': 7,
#  'interval': 11,
#  '+': 6,
#  'types': 6,
#  'RRs': 1,
#  'increase': 16,
#  'categories': 4,
#  'Gy': 1,
#  'CONCLUSIONS': 28,
#  'predisposition': 2,
#  'impact': 4,
#  'dose': 46,
#  'time': 30,
#  'humans': 8,
#  'adulthood': 1,
#  'objective': 7,
#  'cocaine': 9,
#  'rupture': 9,
#  'membranes': 6,
#  'latency': 2,
#  'Urine': 1,
#  'toxicology': 1,
#  'screens': 2,
#  'PROM': 1,
#  'tocolytics': 1,
#  'chorioamnionitis': 2,
#  'heart': 27,
#  'tracing': 1,
#  'urine': 10,
#  'drug': 28,
#  'p': 10,
#  'reason': 2,
#  'segments': 1,
#  'Women': 3,
#  'Responses': 1,
#  'interview': 2,
#  'enrollment': 2,
#  'tests': 6,
#  'users': 3,
#  'alcohol': 5,
#  'fetus': 4,
#  '=': 12,
#  'pregnancy': 27,
#  'half': 2,
#  'transmission': 4,
#  'times': 7,
#  'therapy': 120,
#  'city': 2,
#  'parvovirus': 3,
#  'infection': 37,
#  'BACKGROUND': 16,
#  'implantation': 6,
#  'method': 21,
#  'rehabilitation': 7,
#  'adults': 18,
#  'children': 47,
#  'adult': 15,
#  'strategy': 7,
#  'Results': 3,
#  'tune': 2,
#  'speech': 5,
#  'understanding': 7,
#  'improvement': 8,
#  'set': 3,
#  'effects': 61,
#  'situations': 1,
#  'warning': 3,
#  'signals': 3,
#  'experiences': 3,
#  'pharmacovigilance': 4,
#  'reporting': 1,
#  'type': 26,
#  'B': 19,
#  'reactions': 8,
#  'minority': 2,
#  'dosage': 5,
#  'Examples': 1,
#  'sources': 2,
#  'prescription': 4,
#  'event': 5,
#  'monitoring': 5,
#  'resources': 1,
#  'morbidity': 11,
#  'record': 3,
#  'surveillance': 3,
#  'studies': 40,
#  'proposal': 2,
#  'signal': 8,
#  'procedure': 6,
#  'centres': 2,
#  'steps': 2,
#  'delineation': 1,
#  'literature': 11,
#  'search': 5,
#  'inventory': 2,
#  'collection': 1,
#  'consultation': 3,
#  'companies': 1,
#  'assessment': 17,
#  'conditions': 8,
#  'mechanisms': 7,
#  'strategies': 10,
#  'safety': 16,
#  'efficacy': 25,
#  'methylphenidate': 9,
#  'epilepsy': 2,
#  'attention': 6,
#  'deficit': 3,
#  'hyperactivity': 2,
#  'disorder': 9,
#  'STUDY': 3,
#  'month': 11,
#  'months': 33,
#  'drugs': 22,
#  'AEDs': 2,
#  'morning': 1,
#  'mg': 21,
#  'brain': 21,
#  'tomography': 5,
#  'IQ': 1,
#  'baseline': 5,
#  'performance': 11,
#  'task': 4,
#  'days': 15,
#  'child': 6,
#  'capsule': 4,
#  'placebo': 23,
#  'None': 2,
#  'attacks': 2,
#  'seizures': 5,
#  'change': 10,
#  'reduction': 7,
#  'Side': 2,
#  'Caution': 1,
#  'properties': 6,
#  'processes': 7,
#  'production': 7,
#  'paradigm': 4,
#  'movement': 1,
#  'potentials': 3,
#  'picture': 3,
#  'addition': 11,
#  'choice': 8,
#  'reaction': 17,
#  'no': 1,
#  'go': 2,
#  'categorization': 1,
#  'name': 2,
#  'readiness': 1,
#  'LRPs': 1,
#  'motor': 1,
#  'moments': 1,
#  'position': 5,
#  'phoneme': 1,
#  'trials': 27,
#  'duration': 12,
#  'encoding': 2,
#  'word': 1,
#  'replacement': 8,
#  'tryptophan': 3,
#  'residues': 3,
#  'positions': 3,
#  'glycine': 3,
#  'heterogeneity': 4,
#  'species': 9,
#  'micelles': 2,
#  'interior': 1,
#  'micelle': 1,
#  'alanine': 2,
#  'substitution': 2,
#  'analogs': 3,
#  'concentration': 14,
#  'formation': 14,
#  'dynamics': 8,
#  'torsion': 5,
#  'angle': 7,
#  'space': 2,
#  'resonance': 17,
#  'structure': 9,
#  'calculation': 1,
#  'distances': 2,
#  'coupling': 1,
#  'dihedral': 1,
#  'restraints': 1,
#  'algorithms': 1,
#  'matrix': 2,
#  'geometry': 1,
#  'efficiency': 2,
#  'success': 4,
#  'proteins': 18,
#  'radius': 1,
#  'convergence': 1,
#  'DNA': 6,
#  'strand': 2,
#  'conformation': 1,
#  'proceeds': 2,
#  'minimization': 1,
#  'Tests': 2,
#  'interleukin-8': 1,
#  'T': 4,
#  'base': 6,
#  'duplex': 1,
#  'trypsin': 2,
#  'inhibitor': 6,
#  'monomer': 1,
#  'determination': 3,
#  'wavelet': 2,
#  'transform': 2,
#  'spectroscopy': 4,
#  'shift': 2,
#  'relaxation': 1,
#  'amplitude': 1,
#  'phase': 26,
#  'Wavelet': 1,
#  'transformation': 1,
#  'frequency': 9,
#  'representation': 1,
#  'procedures': 14,
#  'quantification': 1,
#  'Antiplatelet': 1,
#  'aspirin': 14,
#  'anticoagulation': 1,
#  'warfarin': 6,
#  'mortality': 15,
#  'infarction': 25,
#  'monotherapy': 5,
#  'bleeding': 5,
#  'design': 10,
#  'Patients': 7,
#  'tablet': 1,
#  'measurements': 4,
#  'maximum': 1,
#  'FINDINGS': 3,
#  'reinfarction': 1,
#  'stroke': 3,
#  'death': 12,
#  'comparisons': 1,
#  'IQR': 1,
#  'INTERPRETATION': 1,
#  'benefit': 8,
#  'evidence': 36,
#  'pneumoniae': 3,
#  'hypothesis': 8,
#  'macrolide': 1,
#  'events': 14,
#  'angina': 6,
#  'endpoints': 1,
#  'recurrent': 3,
#  'intention': 3,
#  'endpoint': 1,
#  'ischaemia': 1,
#  'scale': 3,
#  'observations': 3,
#  'Stage': 1,
#  'carcinoma': 37,
#  'complications': 20,
#  'trial': 37,
#  'pattern': 3,
#  'recurrences': 1,
#  'institute': 1,
#  'pT2b': 1,
#  'mm': 8,
#  'stroma': 1,
#  'nodes': 3,
#  'outcome': 16,
#  'measures': 3,
#  'recurrence': 10,
#  'diameters': 2,
#  'cm': 4,
#  'range': 9,
#  'multivariate': 1,
#  'diameter': 2,
#  'lymphangiography': 1,
#  'adeno': 1,
#  'histotype': 1,
#  'illness': 5,
#  'cure': 9,
#  'Today': 1,
#  'technology': 5,
#  'health': 44,
#  'providers': 2,
#  'town': 1,
#  'state': 8,
#  'country': 2,
#  'Nursing': 1,
#  'lines': 5,
#  'issues': 6,
#  'introduction': 2,
#  'feeds': 1,
#  'modulation': 1,
#  'PROBLEM': 1,
#  'expression': 18,
#  'lymphocytes': 4,
#  'progesterone': 2,
#  'blocking': 2,
#  'factor': 17,
#  'conception': 2,
#  'cycles': 2,
#  'fertilization': 2,
#  'embryo': 2,
#  'antibody': 14,
#  'invasion': 3,
#  'acids': 15,
#  'centre': 3,
#  'laevorotatory': 1,
#  'L': 2,
#  'dextrorotatory': 1,
#  'compounds': 4,
#  'comet': 1,
#  'impacts': 1,
#  'meteorite': 1,
#  'enantiomers': 1,
#  'possibility': 3,
#  'Earth': 1,
#  'carbon': 3,
#  'isotope': 1,
#  'compositions': 1,
#  'amino': 6,
#  'origin': 10,
#  'overprint': 1,
#  'reservations': 1,
#  'approach': 16,
#  'previsit': 1,
#  'visit': 3,
#  'experience': 12,
#  'miracidia': 1,
#  'ocellata': 1,
#  'host': 5,
#  'snails': 1,
#  'truncatula': 1,
#  'stagnalis': 1,
#  'direction': 4,
#  'gradients': 2,
#  'snail': 2,
#  'water': 3,
#  'turnback': 1,
#  'swimming': 1,
#  'glycoconjugates': 1,
#  'weight': 18,
#  'kDa': 4,
#  'pronase': 1,
#  'oxidation': 1,
#  'cleavage': 6,
#  'carbohydrates': 3,
#  'O': 2,
#  'glycosidically': 1,
#  'serine': 2,
#  'acetylgalactosamine': 2,
#  'Differences': 2,
#  'hosts': 1,
#  'sodium': 7,
#  'sulfate': 1,
#  'gel': 2,
#  'electrophoresis': 2,
#  'carbohydrate': 3,
#  'step': 3,
#  'purification': 1,
#  'components': 2,
#  'ion': 4,
#  'exchange': 3,
#  'chromatography': 3,
#  'determinant': 3,
#  'Tumor': 1,
#  'adenocarcinoma': 4,
#  'pathologist': 2,
#  'regard': 3,
#  'race': 2,
#  'sex': 7,
#  'Blacks': 1,
#  'odds': 2,
#  'ratio': 2,
#  'whites': 1,
#  'summary': 3,
#  'body': 16,
#  'mass': 13,
#  'access': 2,
#  'utilization': 3,
#  'blacks': 3,
#  'activity': 47,
#  'tubule': 1,
#  'ORs': 1,
#  'level': 12,
#  'Comparison': 7,
#  'subsite': 2,
#  'distal': 1,
#  'blood': 29,
#  'vessel': 1,
#  'necrosis': 2,
#  'fibrosis': 3,
#  'histology': 2,
#  'opposite': 1,
#  'tumor': 29,
#  'differential': 1,
#  'exposure': 11,
#  'intensity': 6,
#  'carcinogen': 1,
#  'insult': 1,
#  'biology': 3,
#  'alpha': 18,
#  'glucosidase': 1,
#  'sequencing': 1,
#  'exons': 4,
#  'splice': 4,
#  'deletion': 1,
#  'exon': 1,
#  'dysfunction': 6,
#  'accident': 2,
#  'decade': 1,
#  'purpose': 12,
#  'function': 22,
#  'skin': 8,
#  'R': 4,
#  'sitting': 1,
#  'condition': 3,
#  'correlation': 13,
#  'disturbance': 1,
#  'credits': 1,
#  'semester': 1,
#  'course': 10,
#  'cooperation': 1,
#  'undergraduate': 1,
#  'faculty': 1,
#  'personnel': 1,
#  'units': 3,
#  'problems': 11,
#  'curriculum': 3,
#  'student': 3,
#  'roles': 3,
#  'team': 1,
#  'Objectives': 1,
#  'demonstration': 2,
#  'disablement': 1,
#  'intervention': 6,
#  'simulations': 1,
#  'impairments': 1,
#  'demonstrations': 1,
#  'chart': 1,
#  'reviews': 2,
#  'readings': 1,
#  'audio': 1,
#  'lectures': 1,
#  'review': 17,
#  'consultations': 1,
#  'attendance': 1,
#  'ward': 2,
#  'settings': 3,
#  'neurology': 1,
#  'neurosurgery': 2,
#  'oncology': 2,
#  'psychiatry': 1,
#  'complexity': 3,
#  'neoplasms': 5,
#  'injury': 11,
#  'infections': 14,
#  'others': 1,
#  'process': 11,
#  'person': 1,
#  'modalities': 4,
#  'effectiveness': 20,
#  'electrotherapy': 1,
#  'trigger': 4,
#  'points': 5,
#  'trapezius': 2,
#  'muscle': 12,
#  'males': 4,
#  'females': 3,
#  'side': 5,
#  'muscles': 4,
#  'ROM': 2,
#  '#': 25,
#  'subgroup': 1,
#  'exercise': 23,
#  'citizens': 1,
#  'dancing': 3,
#  'density': 14,
#  'mo': 2,
#  'measuring': 1,
#  'yr': 2,
#  'mineral': 8,
#  'photon': 1,
#  'absorptiometry': 2,
#  'forearm': 1,
#  'qCT': 2,
#  'beginning': 1,
#  'observation': 3,
#  'percentage': 4,
#  'spinal': 4,
#  'r': 3,
#  'dancers': 2,
#  'osteoporosis': 3,
#  'changes': 15,
#  'basal': 4,
#  'Changes': 2,
#  'isoenzyme': 1,
#  'alkaline': 7,
#  'phosphatase': 3,
#  'marker': 3,
#  'prevalence': 9,
#  'trachomatis': 4,
#  'potential': 9,
#  'chain': 9,
#  'tool': 3,
#  'SETTING': 7,
#  'practices': 11,
#  'smear': 1,
#  'check': 1,
#  'specimens': 5,
#  'Prevalence': 2,
#  'sensitivity': 8,
#  'specificity': 7,
#  'immunoassay': 2,
#  'evaluation': 19,
#  'advances': 2,
#  'differentiation': 5,
#  'discoveries': 2,
#  'hormone': 12,
#  'receptor': 23,
#  'etiology': 1,
#  'agenesis': 2,
#  'duct': 3,
#  'female': 1,
#  'embryogenesis': 2,
#  'animal': 7,
#  'fenfluramines': 4,
#  'clinicians': 3,
#  'DATA': 3,
#  'SOURCES': 1,
#  'Archival': 1,
#  'articles': 1,
#  'fenfluramine': 7,
#  'serotonin': 4,
#  'neurotoxicity': 4,
#  'behavior': 8,
#  'loss': 14,
#  'terms': 2,
#  'SELECTION': 1,
#  'Reports': 3,
#  'neurons': 5,
#  'animals': 3,
#  'EXTRACTION': 1,
#  'expertise': 1,
#  'neurobiology': 1,
#  'neuropsychiatry': 1,
#  'appropriateness': 1,
#  'inclusion': 1,
#  'Fenfluramines': 1,
#  'reductions': 2,
#  'routes': 1,
#  'administration': 17,
#  'Doses': 1,
#  'relations': 1,
#  'clearance': 3,
#  'dexfenfluramine': 1,
#  'agents': 18,
#  'imidazoline': 1,
#  'agonists': 3,
#  'claims': 1,
#  'clonidine': 1,
#  'methyldopa': 1,
#  'number': 12,
#  'antihypertensives': 1,
#  'market': 2,
#  'discussion': 1,
#  'techniques': 6,
#  'anxiety': 1,
#  'Examination': 2,
#  'planning': 2,
#  'relation': 5,
#  'needs': 2,
#  'closing': 1,
#  'author': 3,
#  'prevention': 13,
#  'merits': 1,
#  'applicability': 1,
#  'foxes': 4,
#  'Vulpes': 2,
#  'vulpes': 2,
#  'bait': 1,
#  'pellets': 1,
#  'praziquantel': 2,
#  'km2': 2,
#  'baiting': 1,
#  'campaigns': 1,
#  'baits': 1,
#  'cestode': 1,
#  'myeloid': 2,
#  'leukemia': 7,
#  'progenitor': 3,
#  'cells': 45,
#  'apoptosis': 6,
#  'populations': 5,
#  'absence': 7,
#  'insulin': 9,
#  'ceramide': 1,
#  'counterparts': 1,
#  'activation': 18,
#  'mechanism': 8,
#  'kinase': 11,
#  'hallmark': 2,
#  'ability': 6,
#  'lobes': 1,
#  'structures': 2,
#  'memories': 1,
#  'subjects': 19,
#  'lobe': 3,
#  'memory': 5,
#  'system': 21,
#  'amount': 4,
#  'stimulus': 1,
#  'form': 11,
#  'meaning': 2,
#  'involvement': 11,
#  'associations': 2,
#  'imaging': 7,
#  'volunteers': 2,
#  'portions': 1,
#  'parahippocampal': 1,
#  'collateral': 1,
#  'sulcus': 1,
#  'hippocampal': 2,
#  'prevalent': 1,
#  'learning': 3,
#  'capacities': 2,
#  'calcium': 26,
#  'homeostasis': 2,
#  'aging': 5,
#  'neuropathology': 1,
#  'deficits': 3,
#  'forms': 10,
#  'plasticity': 3,
#  'link': 2,
#  'Ca2': 2,
#  'dysregulation': 1,
#  'authors': 8,
#  'regulation': 6,
#  'thresholds': 4,
#  'modification': 4,
#  'depression': 5,
#  'strength': 5,
#  'TEOAEs': 3,
#  'ears': 3,
#  'identification': 4,
#  'selection': 4,
#  'normals': 1,
#  'sizes': 2,
#  'laboratory': 3,
#  'cross': 1,
#  'waveforms': 1,
#  'criterion': 1,
#  'TEOAE': 1,
#  'HTLs': 1,
#  'PRL': 2,
#  'length': 5,
#  'domains': 3,
#  'rat': 9,
#  'Nb2': 1,
#  'aa': 2,
#  'domain': 4,
#  'promoter': 4,
#  'beta': 9,
#  'casein': 1,
#  'element': 1,
#  'reporter': 2,
#  'hamster': 3,
#  'fibroblasts': 2,
#  'cDNAs': 1,
#  'cDNA': 8,
#  'constructs': 1,
#  'peptide': 2,
#  'mutant': 2,
#  'plasma': 16,
#  'membrane': 9,
#  'message': 1,
#  'extent': 2,
#  'cell': 99,
#  'surface': 14,
#  'heterodimerization': 1,
#  'receptors': 6,
#  'transcription': 5,
#  'supplementation': 8,
#  ...}

# %%
pos_propn_list
# Out:
# {'University': 6,
#  'Vermont': 1,
#  'AFI': 5,
#  'June': 2,
#  'August': 5,
#  'Spearman': 1,
#  'Hadassah': 1,
#  'Medical': 5,
#  'Center': 3,
#  'Apgar': 1,
#  'Edward': 2,
#  'Patau': 2,
#  'atresia': 1,
#  'New': 6,
#  'York': 4,
#  'Hospital': 4,
#  'Cornell': 1,
#  'Student': 1,
#  'Chi': 2,
#  '-': 8,
#  'square': 1,
#  'preeclampsia': 12,
#  'eclampsia': 1,
#  'NICUs': 1,
#  'Inter': 1,
#  'Omphalocele': 1,
#  'Exstrophy': 1,
#  'Imperforate': 1,
#  'OEIS': 4,
#  'omphalocele': 1,
#  'hypoplasia': 2,
#  'Nonimmune': 1,
#  'hematoma': 1,
#  'Chronic': 2,
#  'Progressive': 1,
#  'External': 1,
#  'Ophthalmoplegia': 1,
#  'Kearns': 1,
#  'Sayre': 1,
#  'Alzheimer': 7,
#  'presenilin': 2,
#  'N=280': 1,
#  'National': 8,
#  'Insititute': 1,
#  'Neurological': 1,
#  'Disorders': 2,
#  'Stroke': 2,
#  'Disease': 5,
#  'Related': 1,
#  'Association': 6,
#  'DNA': 6,
#  'MAIN': 6,
#  'n=54': 2,
#  '.03': 1,
#  'D12S1042': 1,
#  'MLS': 1,
#  'BRCA1': 6,
#  'MAJOR': 1,
#  'MEASURES': 6,
#  'exon': 2,
#  'HPC1': 4,
#  'Cancer': 6,
#  'Data': 1,
#  'Base': 1,
#  'serum': 6,
#  'P=.01': 1,
#  'MS': 5,
#  'HLA': 4,
#  'MBP': 1,
#  'California': 2,
#  'Beijing': 1,
#  'China': 1,
#  'Chi2': 1,
#  'Testing': 1,
#  'II': 14,
#  'DR2': 1,
#  'DRB1': 3,
#  'DQA1': 1,
#  'DQB1': 1,
#  'D19S178': 1,
#  'D19S574': 1,
#  'APOE': 2,
#  'APOC2': 1,
#  'TO_SEE': 54,
#  'SETTING': 1,
#  'Massachusetts': 3,
#  '/-SE': 1,
#  'Gy': 1,
#  'PROM': 2,
#  'Americans': 1,
#  'Fisher': 3,
#  'HIV': 23,
#  'B19': 1,
#  'Cochlear': 1,
#  'METHODS': 19,
#  'Nucleus': 1,
#  'CI22': 1,
#  'M': 3,
#  'SPEAK': 1,
#  'CIS': 1,
#  'World': 4,
#  'Health': 8,
#  'Organization': 4,
#  'Centre': 2,
#  'International': 9,
#  'Drug': 3,
#  'Monitoring': 1,
#  'ADHD': 2,
#  'kg': 4,
#  'Childhood': 1,
#  'Behavior': 1,
#  'Checklist': 1,
#  'Electroencephalography': 1,
#  'AED': 2,
#  'CPT': 2,
#  'Methylphenidate': 1,
#  'LRP': 2,
#  'A': 16,
#  'Gly-11': 1,
#  'Gly-13': 1,
#  'Gly-15': 1,
#  'SDS': 2,
#  'Gly-9': 1,
#  'Ala-9': 1,
#  'Overhauser': 1,
#  'algorithm': 2,
#  'NMR': 4,
#  'G': 11,
#  'villin': 2,
#  'T': 5,
#  'MRS': 2,
#  'T2': 1,
#  'FID': 1,
#  'Coumadin': 2,
#  'Aspirin': 2,
#  'Reinfarction': 2,
#  'Study': 12,
#  'CARS': 2,
#  'PT': 2,
#  'mg': 10,
#  'INR': 1,
#  'Chlamydia': 3,
#  'roxithromycin': 5,
#  'ischaemia': 1,
#  'Ib': 3,
#  'September': 7,
#  'December': 4,
#  'IIa': 1,
#  'PIBF': 5,
#  'METHOD': 1,
#  'CONCLUSION': 11,
#  'D': 3,
#  'Earth': 1,
#  'Murchison': 2,
#  'Fasciola': 1,
#  'hepatica': 1,
#  'Trichobilharzia': 1,
#  'Lymnaea': 1,
#  'L.': 10,
#  'RCD': 1,
#  'SCW': 3,
#  'NaIO4': 1,
#  'N': 4,
#  'truncatula': 1,
#  'stagnalis': 1,
#  'dodecyl': 1,
#  'Black': 1,
#  'White': 1,
#  'Survival': 1,
#  'OR': 1,
#  'B': 16,
#  'W': 2,
#  'atypia': 1,
#  'GAA': 3,
#  'Glycogen': 1,
#  'Storage': 1,
#  'GSDII': 1,
#  'PCR': 6,
#  'IVS16': 1,
#  '+2': 1,
#  'C': 15,
#  'Parkinson': 7,
#  'palsy': 4,
#  'SSR': 3,
#  'RRIV': 2,
#  'Department': 1,
#  'Physical': 1,
#  'Medicine': 5,
#  'Rehabilitation': 1,
#  'PM': 1,
#  'Johns': 1,
#  'Hopkins': 1,
#  'Human': 1,
#  'Biology': 2,
#  'Biopsychosocial': 1,
#  'Model': 2,
#  'endocrine': 1,
#  'EMS': 1,
#  'a12': 1,
#  'Vienna': 1,
#  'qCT': 1,
#  'Linear': 2,
#  'P': 6,
#  'I': 5,
#  'BMD': 3,
#  'Group': 12,
#  'ligase': 1,
#  'London': 3,
#  'well': 1,
#  'October': 2,
#  'January': 1,
#  'enzyme': 1,
#  'immunoassay': 1,
#  'MEDLINE': 1,
#  'April': 3,
#  'DATA': 1,
#  'SYNTHESIS': 2,
#  'Fenfluramine': 1,
#  'Use': 11,
#  'PPH': 1,
#  'Moxonidine': 2,
#  'Physiotens': 1,
#  'Solvay': 1,
#  'phobia': 1,
#  'Echinococcus': 4,
#  'multilocularis': 2,
#  'Germany': 2,
#  'CML': 4,
#  'BCR': 4,
#  'ABL+': 2,
#  'BAF3': 1,
#  'TNF': 1,
#  'p210': 2,
#  'ABL': 2,
#  'hippocampus': 1,
#  'anterograde': 1,
#  'amnesia': 1,
#  'Ca': 1,
#  'CI': 2,
#  'aa': 1,
#  'PRLR': 3,
#  'delta-19': 2,
#  'PRL': 3,
#  'box': 2,
#  'IU': 1,
#  'D3': 8,
#  '+0.50+/-4.80': 1,
#  '+2.12+/-4.06': 1,
#  '+0.06+/-1.83': 1,
#  '-1.09+/-1.71': 1,
#  'Southern': 2,
#  'Sydney': 2,
#  'Area': 2,
#  'Service': 3,
#  'folic': 1,
#  'Limitation': 1,
#  'niacin': 1,
#  'trivalent': 1,
#  'MMR': 1,
#  'p53-/-': 1,
#  'Msh2-/-': 1,
#  'Reddy': 1,
#  'et': 3,
#  'al': 5,
#  'Radiat': 3,
#  'V79': 3,
#  'RMR': 2,
#  'Tobias': 1,
#  'S77': 1,
#  'S95': 1,
#  'LPL': 3,
#  'S.': 2,
#  'Ostashevsky': 1,
#  'PLD': 2,
#  't': 4,
#  'rep': 7,
#  'DSB': 7,
#  'tau': 4,
#  'DSBR': 2,
#  'Cheong': 1,
#  'PFGE': 2,
#  'ataxia': 1,
#  'telangiectasia': 1,
#  'irs': 1,
#  'CONTEXT': 1,
#  'Adolescents': 3,
#  '259/386': 1,
#  '122/196': 1,
#  '137/190': 1,
#  'Neutrophil': 1,
#  'CSF': 6,
#  'neutrophil': 1,
#  'Food': 3,
#  'Administration': 2,
#  'FDA': 2,
#  'United': 5,
#  'States': 3,
#  'Steinmann': 1,
#  'AO': 1,
#  'hallux': 3,
#  'Arthrodesis': 1,
#  'Harare': 1,
#  'Zimbabwe': 1,
#  'Organisation': 1,
#  '-3.2': 1,
#  '-1.7': 1,
#  'Hg': 2,
#  '-0.1': 1,
#  'CO2': 16,
#  'CO3': 1,
#  'peroxynitrite': 3,
#  '=': 3,
#  'Hoehn': 1,
#  'Yahr': 1,
#  'III': 7,
#  'maximum': 1,
#  'Ropinirole': 3,
#  'GVBD': 2,
#  'A23187': 1,
#  'MeAde': 1,
#  'Dutch': 1,
#  'Belted': 1,
#  'PTH': 2,
#  'BAP': 1,
#  'TRAP': 1,
#  'IGF-1': 5,
#  'crystal': 1,
#  'width': 1,
#  'PURPOSE': 6,
#  'PC': 2,
#  'IOL': 2,
#  'PCCC': 3,
#  'i.e': 4,
#  '.': 4,
#  'HT1A': 1,
#  'hydroxy-2-': 1,
#  '-tetralin': 1,
#  'DPAT': 4,
#  'rainbow': 1,
#  'trout': 1,
#  'Oncorhynchus': 1,
#  'aorta': 1,
#  'cortisol': 1,
#  'ng': 9,
#  'ml': 3,
#  'England': 2,
#  'Outcomes': 1,
#  'S': 10,
#  'F': 4,
#  'mm': 3,
#  'analgesia': 1,
#  'Granulocyte': 1,
#  'myelodysplasia': 1,
#  'EBM': 1,
#  'randomized': 1,
#  'RCT': 1,
#  'UK': 3,
#  'Crohn': 4,
#  'incontinence': 1,
#  'Doppler': 3,
#  'gastritis': 4,
#  'BAO': 3,
#  'MAO': 3,
#  'mmol': 5,
#  'h': 1,
#  'l': 3,
#  'Gastric': 1,
#  'hygromycin': 1,
#  'neomycin': 1,
#  '+': 2,
#  'GH': 1,
#  'DC': 4,
#  'mu': 1,
#  '2b': 1,
#  'CH': 2,
#  '#': 4,
#  'AL': 4,
#  'thickness': 1,
#  'PAI-1': 9,
#  'Pima': 5,
#  'Indians': 5,
#  'RESEARCH': 1,
#  'DESIGN': 1,
#  'Plasma': 2,
#  'Retinopathy': 1,
#  'AU': 1,
#  'BMI': 2,
#  'chi': 1,
#  'PAI-1genotype': 1,
#  'DPL': 2,
#  'phi': 1,
#  'Blastocystis': 1,
#  'glutamine': 5,
#  'carbamoyl': 1,
#  'Hyperammonemia': 1,
#  'OBJECTIVES': 2,
#  'M1': 1,
#  'GSTM1': 4,
#  'General': 2,
#  'Boston': 1,
#  'MA': 1,
#  'USA': 7,
#  'MspI': 2,
#  'CT': 3,
#  'scan': 1,
#  'mesothelioma': 1,
#  'lamina': 1,
#  'electron': 2,
#  'MR': 2,
#  'pallidus': 1,
#  'middle': 2,
#  'radiata': 1,
#  'Broca': 1,
#  'aphasia': 1,
#  'Urine': 2,
#  'THCA': 2,
#  'mL': 9,
#  'Ingestion': 1,
#  'BAEP': 2,
#  'Exact': 1,
#  'Test': 1,
#  'Federated': 2,
#  'Council': 3,
#  'Internal': 2,
#  'Darier': 5,
#  'Localized': 2,
#  'CPD': 4,
#  'Escherichia': 2,
#  'Saccharomyes': 1,
#  'Arabidopsis': 3,
#  'Drosphila': 1,
#  'Crotalus': 1,
#  'Xenopus': 2,
#  'uvr3': 1,
#  'TSS': 5,
#  'multiorgan': 1,
#  'Staphylococcus': 4,
#  'aureus': 4,
#  'BACKGROUND': 2,
#  'germ': 1,
#  'mediastinum': 2,
#  'CaMI': 1,
#  'CaM': 1,
#  'EBCT': 2,
#  'homophobia': 1,
#  'TESE': 2,
#  'ICSI': 3,
#  'TEFNA': 1,
#  'biopsy': 2,
#  'Cyclin': 2,
#  'D1': 3,
#  'G1': 2,
#  'q13': 1,
#  'BCL-1': 1,
#  'human': 3,
#  'lymphoid': 1,
#  'neoplasia': 2,
#  'mantle': 1,
#  'lymphomas': 2,
#  'MCL': 2,
#  'cyclin': 3,
#  'bHLH': 4,
#  'SHARP-1': 1,
#  'SHARP': 2,
#  'SHARP-2': 1,
#  'rat': 3,
#  'cerebral': 1,
#  'cortex': 1,
#  'goat': 2,
#  'Sucrose': 1,
#  'anti': 1,
#  'IgG': 4,
#  'FITC': 1,
#  'Healey': 1,
#  'Walt': 2,
#  'O2': 3,
#  'Li': 1,
#  'Penicillin': 1,
#  'Glucose': 1,
#  'penicillin': 1,
#  'Penicillium': 3,
#  'Pt': 1,
#  'Ag': 1,
#  'AgCl': 1,
#  'Gamma': 2,
#  'y': 2,
#  'BIOSEN': 3,
#  'Med': 3,
#  'L': 1,
#  'x': 1,
#  '1.010x': 1,
#  'operation': 1,
#  'ex': 1,
#  'protein-1': 1,
#  'k1': 1,
#  'k2': 2,
#  'UTI': 3,
#  'dipstick': 1,
#  'U.S': 1,
#  'oocyte': 1,
#  'Drosophila': 3,
#  'fluorescent': 1,
#  'probe': 1,
#  'IMADS': 1,
#  'Lucifer': 2,
#  'Yellow': 2,
#  'lysine': 1,
#  'stage-10': 1,
#  '1b': 1,
#  'codon': 1,
#  'AF-4': 3,
#  'LAF-4': 2,
#  'FMR-2': 2,
#  'LAMP': 1,
#  'chLAMP': 1,
#  'DNAS1L2': 2,
#  'DNAS1L3': 2,
#  'fluorescence': 1,
#  'DNL1L': 1,
#  'DNAS1L1': 2,
#  'DNase': 3,
#  'DNAS1L': 1,
#  'indinavir': 2,
#  'HIV-1': 6,
#  'RNA': 2,
#  'gag': 4,
#  'p7': 4,
#  'p1': 7,
#  'p6': 2,
#  'MT2': 1,
#  'WT': 1,
#  'M46L': 1,
#  'I54V': 1,
#  'V82A': 1,
#  'Indinavir': 1,
#  'granulosus': 1,
#  'EF': 1,
#  'pGEX': 1,
#  'EgCaBP1': 1,
#  'GST': 2,
#  'Pseudomonas': 1,
#  'aeruginosa': 1,
#  'MAP': 4,
#  'Raf-1': 4,
#  'Pa-4': 1,
#  'DeltaRaf-1': 2,
#  'ER': 1,
#  'HMGI': 4,
#  'ERK': 2,
#  'kinase': 5,
#  'MEK': 2,
#  'PD': 1,
#  'ER-': 1,
#  'tetradecanoylphorbol-13': 1,
#  'Raf': 1,
#  'thyroid': 1,
#  'PDS': 2,
#  'Stra10': 2,
#  'P19': 2,
#  'Pbx': 3,
#  'Meis1': 1,
#  'myeloid': 1,
#  'BXH-2': 1,
#  'Nakamura': 1,
#  'Oncogene': 1,
#  'Meis2': 3,
#  'TGIF': 1,
#  'microsatellite': 3,
#  'BTA': 2,
#  '6q21': 3,
#  'HF': 1,
#  'RFLP': 1,
#  'AMOVA': 1,
#  'rabies': 1,
#  'biotype': 1,
#  'dioxin': 2,
#  'testis': 1,
#  'Diabetes': 1,
#  'neuro': 1,
#  'Sumatriptan': 1,
#  'RPE': 1,
#  'ii': 6,
#  'iii': 1,
#  'TQR': 1,
#  'gland': 1,
#  'AT': 2,
#  'Tsa': 1,
#  'Fat': 1,
#  'fatty': 10,
#  'FFAs': 1,
#  'FFA': 3,
#  'glycohaemoglobin': 2,
#  'GHb': 3,
#  'CDUS': 1,
#  'DVT': 1,
#  'Streptomyces': 1,
#  'chrysogenum': 2,
#  'Thom': 2,
#  'Foley': 2,
#  'aspecific': 1,
#  'Dextran': 1,
#  'Polistes': 1,
#  'Micoren': 1,
#  'xylocaine': 1,
#  'labia': 1,
#  'I-131': 1,
#  'Ancona': 1,
#  'icterus': 1,
#  '2d': 2,
#  'Leukoplakia': 1,
#  'Toxemia': 1,
#  'Quo': 1,
#  'Vadis': 1,
#  'Fallot': 1,
#  'Mass': 1,
#  'McLafferty': 1,
#  'Lumbricus': 1,
#  'terrestris': 1,
#  'sulfobromophthalein': 1,
#  'BSP': 1,
#  'Prevention': 7,
#  'Miami': 1,
#  'Mycoplasma': 2,
#  'PPLO': 1,
#  'L1210': 2,
#  'mouse': 1,
#  'leukemia': 1,
#  'American': 10,
#  'Joint': 3,
#  'Committee': 5,
#  'tryptophan': 1,
#  'Muscle': 1,
#  'Origin': 1,
#  'kwashiorkor': 1,
#  'ewe': 1,
#  'gonadotrophin': 2,
#  'lysergic': 2,
#  'LSD-25': 1,
#  'Metabolism': 1,
#  'Profileplasty': 1,
#  'Corpora': 1,
#  'XIX': 1,
#  'Kasumigaseki': 1,
#  'Tokyo': 2,
#  'gel': 2,
#  'endotoxin': 1,
#  'leucocyte': 1,
#  'pyrogen': 1,
#  'LSD': 1,
#  'Institute': 2,
#  'Hygienic': 1,
#  'Sciences': 1,
#  'Standard': 1,
#  'Faculty': 1,
#  'College': 3,
#  'Rhodesia': 1,
#  'acetylneuraminyl-3': 1,
#  'BHK': 1,
#  'Finland': 1,
#  'experimental': 1,
#  'autoimmune': 3,
#  'encephalomelitis': 1,
#  'EAE': 1,
#  'variability': 1,
#  'Ultrastructure': 1,
#  'Dubowitz': 1,
#  'Technical': 1,
#  'Working': 3,
#  'Lamaze': 1,
#  'Bradley': 1,
#  'Victoria': 1,
#  'Australia': 1,
#  'Parameter': 1,
#  'YAG': 1,
#  'Society': 8,
#  'Genetic': 1,
#  'Gonorrhea': 1,
#  'Centers': 3,
#  'Control': 3,
#  'Heart': 2,
#  'verruca': 1,
#  'vulgaris': 1,
#  'CDKN2': 1,
#  'S6': 1,
#  'p90rsk': 1,
#  'eIF4E': 1,
#  'nucleus': 1,
#  'Ste20': 1,
#  'AMP': 1,
#  'PDGF': 1,
#  'phosphatase-1': 1,
#  'AIDS': 10,
#  'VI': 1,
#  'CA': 1,
#  'NH': 1,
#  'nitrogens-15': 1,
#  'nJ': 1,
#  '2D': 2,
#  '1D': 1,
#  'H': 1,
#  'HCCO2': 1,
#  'VII': 2,
#  'ROXIS': 1,
#  'Pilot': 1,
#  'HT2A': 1,
#  'anorexia': 1,
#  'nervosa': 1,
#  'Physician': 1,
#  'Oregon': 2,
#  'America': 2,
#  'Nuremberg': 1,
#  'Guidelines': 3,
#  'Adolescent': 7,
#  'Preventive': 2,
#  'Services': 2,
#  'GPs': 1,
#  'myocarditis': 1,
#  'NN': 1,
#  'Presenilin': 1,
#  'Autoimmune': 1,
#  'Receptor': 3,
#  'Classification': 2,
#  'Integration': 2,
#  'Operational': 2,
#  'Structural': 2,
#  'Information': 2,
#  'Verona': 2,
#  'Italy': 5,
#  'Journal': 1,
#  'HI': 1,
#  'Injury': 1,
#  'Compensation': 1,
#  'Reform': 1,
#  'Act': 1,
#  'Down': 2,
#  'Newbury': 1,
#  'microcephaly': 1,
#  'murine': 1,
#  'multidrug': 1,
#  'MRP': 2,
#  'HL60': 1,
#  'ADR': 1,
#  'Dental': 1,
#  'Commission': 1,
#  'Accreditation': 1,
#  'Healthcare': 1,
#  'Organizations': 1,
#  'Poppy': 1,
#  'ABC': 2,
#  'Africa': 4,
#  'Ethics': 1,
#  'Lansoprazole': 1,
#  'Plasmodium': 1,
#  'Copenhagen': 1,
#  'Dermatobia': 1,
#  'Measles': 1,
#  'Wegener': 2,
#  'Class': 1,
#  'March': 3,
#  'Tayside': 1,
#  'Scotland': 1,
#  'DARTS': 2,
#  'MEMO': 1,
#  'Collaboration': 1,
#  'Vesico': 1,
#  'schizophrenia': 2,
#  'Academy': 4,
#  'Child': 4,
#  'Psychiatry': 4,
#  'Wellington': 1,
#  'SMAC': 1,
#  'Koch': 1,
#  'Stress': 1,
#  'Urinary': 1,
#  'Incontinence': 1,
#  'Clinical': 7,
#  'Panel': 1,
#  'corpus': 1,
#  'Year': 1,
#  'CO': 1,
#  'C18O2': 1,
#  'Autopsy': 1,
#  'Denmark': 3,
#  'Marshall': 1,
#  'Islands': 1,
#  'Dublin': 1,
#  'cloacal': 1,
#  'anomaly': 1,
#  'Kingdom': 2,
#  'Trial': 1,
#  'Karolinska': 1,
#  'Hepatic': 1,
#  'lung': 1,
#  'GAPS': 1,
#  'AMA': 1,
#  'vancomycin': 3,
#  'nasal': 2,
#  'Freeze': 1,
#  'RhD': 1,
#  'HAART': 3,
#  'Psoas': 1,
#  'Norwegian': 1,
#  'Gastrointestinal': 1,
#  'Vancomycin': 1,
#  'Acute': 3,
#  'hydrocephalus': 1,
#  'Listeria': 2,
#  'LDL': 2,
#  'IV': 3,
#  'V': 1,
#  'dDP': 1,
#  'dE2F': 1,
#  'E': 2,
#  'E2F': 1,
#  'ABO': 1,
#  'Netherlands': 2,
#  'Comprehensive': 1,
#  'West': 1,
#  'Leiden': 1,
#  'Intra-': 1,
#  'Fulminant': 1,
#  'hepatitis': 7,
#  'Overactive': 1,
#  'Bladder': 1,
#  'Basic': 2,
#  'Science': 1,
#  'Management': 2,
#  'Consensus': 2,
#  'Conference': 4,
#  'AACC': 1,
#  'Lectureship': 1,
#  'Award': 1,
#  'Address': 1,
#  'Bizarro': 1,
#  'calmodulin': 1,
#  'Fibromyalgia': 1,
#  'Vive': 1,
#  'Malade': 1,
#  'Electron': 1,
#  'tomographic': 1,
#  'OWA': 1,
#  'Henneguya': 1,
#  'salminicola': 1,
#  'stool': 1,
#  'Pressure-': 1,
#  'Volume': 1,
#  'Limited': 1,
#  'Ventilation': 1,
#  'Strategy': 1,
#  'Variation': 1,
#  'Distinction': 1,
#  'postmenopausal': 1,
#  'Montana': 1,
#  'Tourette': 1,
#  'A2': 2,
#  'H2': 1,
#  'Part': 2,
#  'Enzyme': 1,
#  'sera': 1,
#  'kala': 1,
#  'azar': 1,
#  'haemophilia': 2,
#  'German': 1,
#  'Bioinformatics': 1,
#  "GCB'96": 1,
#  'surface': 1,
#  'plasmon': 1,
#  'Overt': 1,
#  'Aggression': 1,
#  'Scale': 1,
#  'RCOG': 1,
#  'BAUS': 1,
#  'IVADs': 1,
#  'hemophilia': 3,
#  'Hemophilia': 1,
#  'Growth': 1,
#  'Development': 1,
#  'Portland': 1,
#  'French': 2,
#  'Guiana': 1,
#  'Helicobacter': 4,
#  'trnY': 1,
#  'interferon': 8,
#  'February': 3,
#  'Erysiphe': 1,
#  'graminis': 1,
#  'f.sp': 1,
#  'glyceraldehyde-3': 1,
#  'Washington': 2,
#  'Symposium': 3,
#  'Pharmacology': 1,
#  'Memphis': 1,
#  'Tennessee': 1,
#  'Breckenridge': 1,
#  'Colorado': 1,
#  'Gynecology': 1,
#  'Endocrinology': 1,
#  'Aspects': 3,
#  'Athens': 1,
#  'Greece': 2,
#  '3rd': 2,
#  'Neuroprotective': 1,
#  'Agents': 1,
#  'Experimental': 1,
#  'Lake': 1,
#  'Como': 1,
#  'Exon': 1,
#  'intron': 3,
#  'Gag': 1,
#  'Mar': 1,
#  'del': 1,
#  'Plata': 1,
#  'Argentina': 1,
#  'Cynictis': 1,
#  'ETTIN': 1,
#  'Chironomus': 1,
#  'thummi': 1,
#  'Populus': 2,
#  'Pax-2': 1,
#  'Workshop': 2,
#  'Bone': 1,
#  'Research': 1,
#  'Japan': 2,
#  'November': 2,
#  'Congress': 3,
#  'Transfusion': 1,
#  'Marseille': 1,
#  'France': 2,
#  'East': 1,
#  'European': 4,
#  'Regional': 1,
#  'INTERASMA': 1,
#  'Budapest': 1,
#  'Hungary': 1,
#  'Sarasota': 1,
#  'Florida': 1,
#  'tÃƒ': 2,
#  'c': 5,
#  'de': 3,
#  'Pharmaco': 1,
#  'Toxicologie': 2,
#  'Cellulaire': 1,
#  'Italian': 1,
#  'Glaucoma': 1,
#  'Rapallo': 1,
#  'Scientific': 1,
#  'Meeting': 3,
#  'Rheumatology': 1,
#  'USAN': 1,
#  'Radiology': 2,
#  'Lower': 1,
#  'Saxony': 1,
#  'Sachsen': 1,
#  'Anhalt': 1,
#  'Kiel': 1,
#  'Cologne': 1,
#  'Integrative': 1,
#  'Systems': 1,
#  'Advances': 1,
#  'NeuroImmunoModulation': 1,
#  'ISNIM': 1,
#  'Dysmorphology': 1,
#  'Strasbourg': 1,
#  'EU': 1,
#  'Tobacco': 1,
#  'Oral': 1,
#  'NIH': 1,
#  'Therapeutic': 1,
#  'Oligonucleotides': 1,
#  'Transcription': 1,
#  'Factors': 1,
#  'Signaling': 1,
#  'Pathways': 1,
#  'Cell': 1,
#  'Phagocytes': 1,
#  'Catania': 1,
#  'May': 2,
#  'Brandon': 1,
#  'Hill': 1,
#  'TSG101': 1,
#  'migraine': 1,
#  'Factor': 1,
#  'Epstein': 1,
#  'Barr': 1,
#  'Creutzfeldt': 2,
#  'Jakob': 2,
#  'intramedullary': 1,
#  'lobe': 1,
#  'epilepsy': 1,
#  'Eosinophilic': 1,
#  'meningitis': 4,
#  'Vascular': 1,
#  'Epilepsy': 1,
#  'Metronidazole': 1,
#  'Flagyl': 1,
#  'Preterm': 1,
#  'Prediction': 1,
#  'Bombyx': 1,
#  'L1Bm': 1,
#  'Lyme': 1,
#  ...}

# %%
# Initialise 
noun_counter = Counter(pos_noun_list)
propn_counter = Counter(pos_propn_list)

# %%
# Display the top 25 common nouns
noun_counter.most_common(25)
# Out:
# [('patients', 354),
#  ('treatment', 195),
#  ('%', 161),
#  ('cancer', 135),
#  ('therapy', 120),
#  ('disease', 105),
#  ('study', 103),
#  ('cell', 99),
#  ('lung', 86),
#  ('chemotherapy', 65),
#  ('group', 63),
#  ('effects', 61),
#  ('gene', 54),
#  ('results', 54),
#  ('use', 53),
#  ('surgery', 51),
#  ('survival', 50),
#  ('risk', 49),
#  ('women', 48),
#  ('care', 47),
#  ('analysis', 47),
#  ('children', 47),
#  ('activity', 47),
#  ('rate', 46),
#  ('cases', 46)]

# %%
# Display the top 25 common propositions
propn_counter.most_common(25)
# Out:
# [('TO_SEE', 54),
#  ('HIV', 23),
#  ('METHODS', 19),
#  ('A', 16),
#  ('B', 16),
#  ('CO2', 16),
#  ('C', 15),
#  ('II', 14),
#  ('nsclc', 14),
#  ('preeclampsia', 12),
#  ('Study', 12),
#  ('Group', 12),
#  ('G', 11),
#  ('CONCLUSION', 11),
#  ('Use', 11),
#  ('mg', 10),
#  ('L.', 10),
#  ('S', 10),
#  ('fatty', 10),
#  ('American', 10),
#  ('AIDS', 10),
#  ('International', 9),
#  ('ng', 9),
#  ('PAI-1', 9),
#  ('mL', 9)]

# %%
# Let's define the features to get the feature value of one word.
# We will use custom NER processing using custom feature functions

def getFeaturesOfOneWord(sentence, pos):
  word = sentence[pos]

  # Define features with PoS tag as one of the features
  features = [
    'word.lower=' + word.lower(), # serves as word id
    'word[-3:]=' + word[-3:],     # last three characters
    'word[-2:]=' + word[-2:],     # last two characters
    'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
    'word.isdigit=%s' % word.isdigit(),  # is the word a number
    'word.startsWithCapital=%s' % word[0].isupper(), # is the word starting with a capital letter
  ]

  # Use the previous word also while defining features
  if(pos > 0):
    prev_word = sentence[pos-1]
    features.extend([
    'prev_word.lower=' + prev_word.lower(), 
    'prev_word.isupper=%s' % prev_word.isupper(),
    'prev_word.isdigit=%s' % prev_word.isdigit(),
    'prev_word.startsWithCapital=%s' % prev_word[0].isupper(),
  ])
    
  # Mark the begining and the end words of a sentence correctly in the form of features.
  else:
    features.append('BEG') # feature to track begin of sentence 

  if(pos == len(sentence)-1):
    features.append('END') # feature to track end of sentence

  return features

# %%
# Write a code to get features of a sentence.

def getFeaturesOfOneSentence(sentence):

  word_list = sentence.split()
  
  return [getFeaturesOfOneWord(word_list, pos) for pos in range(len(word_list))]

# %%
# Test the sentence function to view the output, i.e. features of its words
print(getFeaturesOfOneSentence("The rain in Spain falls mainly on the plains"))
# Out:
# [['word.lower=the', 'word[-3:]=The', 'word[-2:]=he', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=True', 'BEG'], ['word.lower=rain', 'word[-3:]=ain', 'word[-2:]=in', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=the', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=True'], ['word.lower=in', 'word[-3:]=in', 'word[-2:]=in', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=rain', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False'], ['word.lower=spain', 'word[-3:]=ain', 'word[-2:]=in', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=True', 'prev_word.lower=in', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False'], ['word.lower=falls', 'word[-3:]=lls', 'word[-2:]=ls', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=spain', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=True'], ['word.lower=mainly', 'word[-3:]=nly', 'word[-2:]=ly', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=falls', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False'], ['word.lower=on', 'word[-3:]=on', 'word[-2:]=on', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=mainly', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False'], ['word.lower=the', 'word[-3:]=the', 'word[-2:]=he', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=on', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False'], ['word.lower=plains', 'word[-3:]=ins', 'word[-2:]=ns', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'prev_word.lower=the', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False', 'END']]

# %%
# Write a code to get the labels for a sentence.
def getLabelsInListOfOneSentence(labels):
  return labels.split()

# %%
X_train = [getFeaturesOfOneSentence(sentence) for sentence in train_sentences]
X_test = [getFeaturesOfOneSentence(sentence) for sentence in test_sentences]

# %%
Y_train = [getLabelsInListOfOneSentence(labels) for labels in train_labels]
Y_test = [getLabelsInListOfOneSentence(labels) for labels in test_labels]

# %%
# Build the CRF model.

crf = sklearn_crfsuite.CRF(max_iterations=100)
crf.fit(X_train, Y_train)
# Out:
# CRF(max_iterations=100)

# %%
# Get the predicted values from the model by passing in the test values
Y_pred = crf.predict(X_test)

# %%
# Calculate the f1 score using the test data
metrics.flat_f1_score(Y_test, Y_pred, average='weighted')
# Out:
# 0.9042560946986944

# %%
# We will check the predictions of the model looking at some of the test sentences
id = 1
print("Sentence:", test_sentences[id])
print("Original Labels:", Y_test[id])
print("Predicted Labels:", Y_pred[id])
# Out:
# Sentence: As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration
# Original Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
id = 699
print("Sentence:", test_sentences[id])
print("Original Labels:", Y_test[id])
print("Predicted Labels:", Y_pred[id])
# Out:
# Sentence: Serologic evidence for mother-to-child transmission of Kaposi sarcoma-associated herpesvirus infection
# Original Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'D', 'D', 'D', 'D']
# Predicted Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'D', 'D', 'D', 'D']

# %%
# Prepare an empty dictionary to store the diseases and treatments
diseases_and_treatments =  {}

# Scroll through the all predictions
for pred_counter in range(len(Y_pred)):
  
  label = Y_pred[pred_counter]

  disease = ""
  treatment = ""
  
  # Each label is a list, so scroll through those 
  for label_counter in range(len(label)): # for each individual label in the sequence
    # If the label is O then skip this label and go to the next one
    if label[label_counter] == 'O':
      continue
    
    #
    # The understanding here is that the disease and the treatments are in the same sentence
    #
    # If the label is identified as D, i.e. disease, add the word to the list in the disease variable
    if(label[label_counter] == 'D'):
      disease += test_sentences[pred_counter].split()[label_counter] + " "
      continue
    
    # If the label is identified as T, i.e. treatment, add the word to the dictionary in the treatment variable
    if(label[label_counter] == 'T'):
      # print(test_sentences[i].split()[j])
      treatment += test_sentences[pred_counter].split()[label_counter] + " "

  # Remove the extra spaces
  disease = disease.strip()
  treatment = treatment.strip()

  # Add the identified disease and treatment to the dictionary
  # if it is a new disease, directly add the value
  # if the disease has been seen previously, get the treatment list
  # and add current treatment to the list.
  if disease != "" and treatment != "":
    if disease not in diseases_and_treatments.keys():
      diseases_and_treatments[disease] = [treatment]
    else:
      treatment_list = diseases_and_treatments.get(disease)
      treatment_list.append(treatment)
      diseases_and_treatments[disease] = treatment_list

# %%
search_item = 'hereditary retinoblastoma'
treatments = diseases_and_treatments[search_item]
print("Treatment(s) for '{0}' is '{1}'".format(search_item,"".join(treatments)), end = "")
# Out:
# Treatment(s) for 'hereditary retinoblastoma' is 'radiotherapy'
